# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

from diploma.utils import estimate_blur, estimate_pitch, estimate_yaw, crop_by_coordinates
from diploma.models.detector import FaceDetector

# %%
x = cv2.imread('E:\kbtu_courses\diploma_project\src\diploma\photos\SCRFD_check\Big_photo.jpg')

# %%
detector = FaceDetector("E:\kbtu_courses\diploma_project\src\diploma\models\detector\weights\model_detector.onnx")

boxes, landmarks = detector.detect(x, input_size=(640, 640))

# %%
print(boxes)
print(landmarks)
# Out:
# [[2.7680188e+02 4.2160114e+02 7.4265332e+02 1.0430249e+03 8.3395481e-01]]
# [[[391.3505  669.61334]
#   [611.08167 665.7191 ]
#   [497.92926 795.2056 ]
#   [424.10382 910.9147 ]
#   [587.6163  908.2309 ]]]

# %%
crop = crop_by_coordinates(x, boxes[0, :4])

# %%
plt.imshow(crop)

# %%
estimate_pitch(landmarks[0])
# Out:
# 0.053645696

# %%
estimate_yaw(landmarks[0])
# Out:
# -0.08516197373360457

# %%
estimate_blur(crop)
# Out:
# 25.242550821934863

# %%
x = cv2.imread('E:/kbtu_courses/diploma_project/src/diploma/photos/blur_2.jpg')

# %%
boxes, landmarks = detector.detect(x, input_size=(640, 640))

# %%
crop = crop_by_coordinates(x, boxes[0, :4])

# %%
estimate_blur(crop)
# Out:
# 31.956132273634687

# %%
x = cv2.imread('E:/kbtu_courses/diploma_project/src/diploma/photos/blur_1.jpg')
boxes, landmarks = detector.detect(x, input_size=(640, 640))

# %%
crop = crop_by_coordinates(x, boxes[0, :4])

# %%
estimate_blur(x)
# Out:
# 46.4355200191809
